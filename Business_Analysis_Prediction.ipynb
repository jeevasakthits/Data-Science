# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler # Used for scaling of data
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras
import tdu
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
# Read in train data
df_train = pd.read_csv('fs1_training.csv')

# %%
df_train.columns
# Out:
# Index(['serial_number', 'time_stamp', 'Sector 1', 'Sector 2', 'Sector 3',
#        'Sector 4'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1049 entries, 0 to 1048
# Data columns (total 6 columns):
# serial_number    1049 non-null int64
# time_stamp       1049 non-null object
# Sector 1         1049 non-null float64
# Sector 2         1049 non-null float64
# Sector 3         1049 non-null float64
# Sector 4         1049 non-null float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 49.2+ KB

# %%
df_train.dropna(inplace = True)

# %%
cols = ['Sector 1', 'Sector 2', 'Sector 3','Sector 4']

# %%
df2=pd.DataFrame()

# %%
df_train=df2

# %%
df_train.columns
# Out:
# Index(['Sector 1', 'Sector 2', 'Sector 3', 'Sector 4'], dtype='object')

# %%
df_train.head()
# Out:
#    Sector 1  Sector 2  Sector 3  Sector 4
# 0   1125.36    458.49   2048.98   1275.00
# 1   1120.10    458.49   2048.98   1242.46
# 2   1120.10    458.49   2048.98   1242.46
# 3   1117.84    458.49   2048.98   1228.52
# 4   1114.08    458.49   2048.98   1205.28

# %%
X_test=df2

# %%
X_test = X_test[[ 'Sector 1', 'Sector 2','Sector 4']]
X_train = df_train[['Sector 1', 'Sector 2','Sector 4']]

# %%
#bigdata = X_train.append(X_test, ignore_index=True)

# %%
#bigdata
# Out:
#        Sector 1  Sector 2   Sector 4
# 0     1125.3600    458.49  1275.0000
# 1     1120.1000    458.49  1242.4600
# 2     1120.1000    458.49  1242.4600
# 3     1117.8400    458.49  1228.5200
# 4     1114.0800    458.49  1205.2800
# 5     1113.8199    458.49  1205.2800
# 6     1112.3199    458.49  1195.9800
# 7     1108.7500    458.49  1182.0400
# 8     1111.8800    470.07  1182.0400
# 9     1111.8800    470.07  1182.0400
# 10    1111.8800    470.07  1182.0400
# 11    1111.8800    470.07  1182.0400
# 12    1111.8800    470.07  1182.0400
# 13    1112.6300    470.07  1186.6899
# 14    1113.9500    470.07  1195.9800
# 15    1114.3400    470.07  1191.3300
# 16    1115.0900    470.07  1195.9800
# 17    1114.5100    470.07  1205.2800
# 18    1114.5100    470.07  1205.2800
# 19    1116.2000    470.07  1205.2800
# 20    1117.7000    470.07  1214.5699
# 21    1115.9800    470.07  1207.7100
# 22    1115.9500    470.07  1207.7100
# 23    1115.1000    470.07  1204.2800
# ...

# %%
len(X_train)
# Out:
# 1049

# %%
X_train
# Out:
#        Sector 1  Sector 2   Sector 4
# 0     1125.3600    458.49  1275.0000
# 1     1120.1000    458.49  1242.4600
# 2     1120.1000    458.49  1242.4600
# 3     1117.8400    458.49  1228.5200
# 4     1114.0800    458.49  1205.2800
# 5     1113.8199    458.49  1205.2800
# 6     1112.3199    458.49  1195.9800
# 7     1108.7500    458.49  1182.0400
# 8     1111.8800    470.07  1182.0400
# 9     1111.8800    470.07  1182.0400
# 10    1111.8800    470.07  1182.0400
# 11    1111.8800    470.07  1182.0400
# 12    1111.8800    470.07  1182.0400
# 13    1112.6300    470.07  1186.6899
# 14    1113.9500    470.07  1195.9800
# 15    1114.3400    470.07  1191.3300
# 16    1115.0900    470.07  1195.9800
# 17    1114.5100    470.07  1205.2800
# 18    1114.5100    470.07  1205.2800
# 19    1116.2000    470.07  1205.2800
# 20    1117.7000    470.07  1214.5699
# 21    1115.9800    470.07  1207.7100
# 22    1115.9500    470.07  1207.7100
# 23    1115.1000    470.07  1204.2800
# ...

# %%
X_train
# Out:
#        Sector 1  Sector 2   Sector 4
# 0     1125.3600    458.49  1275.0000
# 1     1120.1000    458.49  1242.4600
# 2     1120.1000    458.49  1242.4600
# 3     1117.8400    458.49  1228.5200
# 4     1114.0800    458.49  1205.2800
# 5     1113.8199    458.49  1205.2800
# 6     1112.3199    458.49  1195.9800
# 7     1108.7500    458.49  1182.0400
# 8     1111.8800    470.07  1182.0400
# 9     1111.8800    470.07  1182.0400
# 10    1111.8800    470.07  1182.0400
# 11    1111.8800    470.07  1182.0400
# 12    1111.8800    470.07  1182.0400
# 13    1112.6300    470.07  1186.6899
# 14    1113.9500    470.07  1195.9800
# 15    1114.3400    470.07  1191.3300
# 16    1115.0900    470.07  1195.9800
# 17    1114.5100    470.07  1205.2800
# 18    1114.5100    470.07  1205.2800
# 19    1116.2000    470.07  1205.2800
# 20    1117.7000    470.07  1214.5699
# 21    1115.9800    470.07  1207.7100
# 22    1115.9500    470.07  1207.7100
# 23    1115.1000    470.07  1204.2800
# ...

# %%
#train,test=X_train[:1049,:],X_train[1049:,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-240-1634bcf79b82> in <module>()
# ----> 1 train,test=X_train[:1049,:],X_train[1049:,:]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# ...

# %%
#def norm(x):
#  return (x - train_stats['mean']) / train_stats['std']
#normed_train_data = norm(train_dataset)
#normed_test_data = norm(test_dataset)

# %%
from __future__ import absolute_import, division, print_function

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation=tf.nn.relu, input_shape=[len(X_train.keys())]),
    layers.Dense(64, activation=tf.nn.relu),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model

# %%
"""def create_model():
    # create model
    model = Sequential()
    model.add(Dense(30, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(90, activation='relu'))
    model.add(Dense(90, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', 
              metrics =[metrics.mae])
    return model

model = create_model()
model.summary()"""
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_21 (Dense)             (None, 30)                120
# _________________________________________________________________
# dense_22 (Dense)             (None, 90)                2790
# _________________________________________________________________
# dense_23 (Dense)             (None, 90)                8190
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 91
# ...
# Total params: 11,191
# Trainable params: 11,191
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = build_model()
# Out:
# W0615 17:12:15.168491 139731690719104 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
history = model.fit(X_train, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 1049/1049 [==============================] - 0s 48us/sample - loss: 2934.5933 - mean_absolute_error: 34.5489 - mean_squared_error: 2934.5933
# Epoch 2/1000
# 1049/1049 [==============================] - 0s 39us/sample - loss: 2605.8384 - mean_absolute_error: 31.9874 - mean_squared_error: 2605.8384
# Epoch 3/1000
# 1049/1049 [==============================] - 0s 42us/sample - loss: 2775.0758 - mean_absolute_error: 33.9999 - mean_squared_error: 2775.0754
# Epoch 4/1000
# 1049/1049 [==============================] - 0s 47us/sample - loss: 2888.7938 - mean_absolute_error: 33.6886 - mean_squared_error: 2888.7935
# Epoch 5/1000
# 1049/1049 [==============================] - 0s 44us/sample - loss: 3069.8174 - mean_absolute_error: 36.6716 - mean_squared_error: 3069.8171
# Epoch 6/1000
# 1049/1049 [==============================] - 0s 43us/sample - loss: 2693.9679 - mean_absolute_error: 34.1794 - mean_squared_error: 2693.9675
# Epoch 7/1000
# ...

# %%
prediction= model.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix

rmse = sqrt(mean_squared_error(y_train, prediction))


model.summary()

rmse
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# ...
# Total params: 4,481
# Trainable params: 4,481
# Non-trainable params: 0
# _________________________________________________________________
# 65.65642634862571

# %%
print(min(df_train['Sector 3']))
print(max(df_train['Sector 3']))
# Out:
# 1047.34
# 2101.6499

# %%
prediction= model.predict(X_test)

# %%
prediction
# Out:
# array([[2281.6802],
#        [2275.6208],
#        [2279.2766],
#        [2276.263 ],
#        [2287.5366],
#        [2300.1106],
#        [2299.1912],
#        [2281.6912],
#        [2279.0837],
#        [2279.0837],
#        [2279.7317],
#        [2279.0837],
#        [2264.2805],
#        [2266.6555],
#        [2267.3064],
#        [2267.954 ],
#        [2264.2805],
#        [2264.9307],
#        [2279.7317],
#        [2279.0837],
#        [2274.3528],
#        [2274.3528],
#        [2281.822 ],
#        [2281.822 ],
#        [2281.822 ],
#        [2281.822 ],
#        [2259.9744],
#        [2259.9744],
#        [2259.9744],
#        [2260.6055],
#        [2260.6133],
#        [2260.6133],
#        [2260.6133],
#        [2246.2412],
#        [2246.2412],
#        [2246.8313],
#        [2268.68  ],
#        [2268.68  ],
#        [2262.0977],
#        [2260.2263],
#        [2259.5762],
#        [2258.9255],
#        [2259.6672],
#        [2258.3882],
#        [2244.297 ],
# ...

# %%
submission = pd.DataFrame()
submission['Sector 3'] = prediction[:,0]
submission.to_csv("output.csv")

# %%
bigdata = X_train.append(X_test, ignore_index=True)

# %%
bigdata
# Out:
#        Sector 1  Sector 2   Sector 4
# 0     1125.3600    458.49  1275.0000
# 1     1120.1000    458.49  1242.4600
# 2     1120.1000    458.49  1242.4600
# 3     1117.8400    458.49  1228.5200
# 4     1114.0800    458.49  1205.2800
# 5     1113.8199    458.49  1205.2800
# 6     1112.3199    458.49  1195.9800
# 7     1108.7500    458.49  1182.0400
# 8     1111.8800    470.07  1182.0400
# 9     1111.8800    470.07  1182.0400
# 10    1111.8800    470.07  1182.0400
# 11    1111.8800    470.07  1182.0400
# 12    1111.8800    470.07  1182.0400
# 13    1112.6300    470.07  1186.6899
# 14    1113.9500    470.07  1195.9800
# 15    1114.3400    470.07  1191.3300
# 16    1115.0900    470.07  1195.9800
# 17    1114.5100    470.07  1205.2800
# 18    1114.5100    470.07  1205.2800
# 19    1116.2000    470.07  1205.2800
# 20    1117.7000    470.07  1214.5699
# 21    1115.9800    470.07  1207.7100
# 22    1115.9500    470.07  1207.7100
# 23    1115.1000    470.07  1204.2800
# ...

# %%
from sklearn import preprocessing

# %%
normalized_X = preprocessing.normalize(bigdata)

# %%
# Out:
# array([[0.63892731, 0.2603094 , 0.72388598],
#        [0.64577112, 0.26433318, 0.71631531],
#        [0.64577112, 0.26433318, 0.71631531],
#        ...,
#        [0.64675711, 0.26491653, 0.71520939],
#        [0.64577112, 0.26433318, 0.71631531],
#        [0.64380049, 0.26317411, 0.71851257]])

# %%
X_train=normalized_X

# %%
X_train
# Out:
# array([[0.63892731, 0.2603094 , 0.72388598],
#        [0.64577112, 0.26433318, 0.71631531],
#        [0.64577112, 0.26433318, 0.71631531],
#        ...,
#        [0.64675711, 0.26491653, 0.71520939],
#        [0.64577112, 0.26433318, 0.71631531],
#        [0.64380049, 0.26317411, 0.71851257]])

# %%
train,test=X_train[:1049,:],X_train[1049:,:]

# %%
train
# Out:
# array([[0.63892731, 0.2603094 , 0.72388598],
#        [0.64577112, 0.26433318, 0.71631531],
#        [0.64577112, 0.26433318, 0.71631531],
#        ...,
#        [0.56235688, 0.45499084, 0.69046222],
#        [0.56106589, 0.46393478, 0.68554328],
#        [0.56106589, 0.46393478, 0.68554328]])

# %%
test
# Out:
# array([[0.58715806, 0.3478082 , 0.73094109],
#        [0.58727822, 0.34976191, 0.72991157],
#        [0.59003456, 0.34515705, 0.72988069],
#        ...,
#        [0.64675711, 0.26491653, 0.71520939],
#        [0.64577112, 0.26433318, 0.71631531],
#        [0.64380049, 0.26317411, 0.71851257]])

# %%
X_train=train

# %%
X_test=test

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)
prediciotn=reg.predict(X_test)

# %%
submission = pd.DataFrame()
submission['Sector 3'] = prediciotn
submission.to_csv("output.csv")

# %%
prediciotn
# Out:
# array([1785.65919838, 1782.5065016 , 1794.26304027, 1793.56057174,
#        1787.99185757, 1791.38666498, 1792.35955903, 1787.53916105,
#        1790.47640492, 1790.47640492, 1790.61660251, 1790.47640492,
#        1814.07578133, 1810.04877881, 1810.16445638, 1810.2803829 ,
#        1814.07578133, 1814.18632313, 1790.61660251, 1790.47640492,
#        1798.34360087, 1798.34360087, 1800.39147527, 1800.39147527,
#        1800.39147527, 1800.39147527, 1836.23870028, 1836.23870028,
#        1836.23870028, 1836.31378837, 1836.31881375, 1836.31881375,
#        1836.31881375, 1832.40726441, 1832.40726441, 1832.4967138 ,
#        1794.47538086, 1794.47538086, 1792.6054655 , 1794.70078878,
#        1794.56140469, 1794.4231027 , 1796.82428237, 1796.5554982 ,
#        1792.68519613, 1792.83142962, 1792.83142962, 1794.84649091,
#        1794.98820736, 1794.98820736, 1794.84649091, 1794.98820736,
#        1794.84649091, 1795.70438402, 1798.83471643, 1802.9723152 ,
# ...

# %%
df_train['Sector 1'].plot.box(grid='True')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
import matplotlib.pyplot as plt
plt.plot(prediciotn)
plt.ylabel('prediction')
plt.show()
