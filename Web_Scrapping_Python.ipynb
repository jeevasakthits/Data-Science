# %%
#importing required packages
import requests
import urllib.request
import HTMLParser
import lxml
import pandas as pd

# %%
#Reading Input for the analysis user choose the company need to know
inp=input("Enter You Required Company")
# Out:
# Enter You Required Companygoogle

# %%
#Collecting data from trustpilot for particular company
for i in range(1,1000):
    try:
        r=requests.get("https://www.trustpilot.com/review/www."+inp+".com?page="+str(i))
        soup = BeautifulSoup(r.text, "lxml")
        
    except:
        print("Ended page for read")
        break
print(value)
# Out:
# ['Excellent marketplace', 'I love Amazon', 'This is a minus 10 review rating', 'Account on Hold. No notification. No explanation. Keep charging Prime Subscription', 'Poor customer service, falsified shipping guarantees', 'Can I give -1000 stars?', 'Outrageous attitude of account…', 'Great and reliable (prime)', "I've enjoyed Amazon for years but…", 'Amazon has gone way down hill.', 'Such worst app eva..', 'If they had a zero star rating would be…', 'I have been buying from Amazon a lot in…', 'Delivery driver lied, never showed and claimed no access to the property', 'They signed me up for prime without my consent', 'All I needed was to change my old work…', 'Best best best service of all', 'Next Day Shipping is Great', 'Absolutely horrible', 'wrost amazon service , product or seller have good produt', 'All of the stuff I order from here is…', 'Again', 'The worst online place to buy from is amazon', 'Amazon is a modern miracle', 'Got rid of postage one.', 'Ridiculous delivery delays',
# ...

# %%
#Storing scrabbed data into csv file
webscrp=pd.DataFrame()
webscrp["amazon_reviews"]=value
len(value)
webscrp.to_csv("Amazon.csv")

# %%
data=pd.read_csv("Amazon.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                     amazon_reviews
# 0           0                              Excellent marketplace
# 1           1                                      I love Amazon
# 2           2                   This is a minus 10 review rating
# 3           3  Account on Hold. No notification. No explanati...
# 4           4  Poor customer service, falsified shipping guar...

# %%
data1=data.drop(["Unnamed: 0"],axis=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(binary=True)

cv.fit(data1["amazon_reviews"])
X=cv.transform(data1["amazon_reviews"])
x_test=cv.transform(data1["amazon_reviews"])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
#response = requests.get(url)

# %%
#soup=BeautifulSoup(response.text,'html.parser')

# %%
#one_a_tag=soup.findAll('a')

# %%
#review=soup.select(".review-content__title")

# %%
#for i in range(len(review)):
 # review[i]=review[i].text.strip()

# %%
#review
# Out:
# [<h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/544ae4d80000640002aed8e1">Shipping is too high</a>
#  </h2>, <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/544ab8b10000640002aed3b2">very good control of sellers and excellent service</a>
#  </h2>, <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/544964190000640002ae92b6">Excellent stuff and excellent prices</a>
#  </h2>, <h2 class="review-content__title">
#  <a class="link link--large link--dark" data-track-link="{'target': 'Single review', 'name': 'review-title'}" href="/reviews/5447b6590000640002ae32ba">Great company  with great partners</a>
#  </h2>, <h2 class="review-content__title">
# ...

# %%
#value=[]

# %%
# Out:
# ['Excellent marketplace', 'I love Amazon', 'This is a minus 10 review rating', 'Account on Hold. No notification. No explanation. Keep charging Prime Subscription', 'Poor customer service, falsified shipping guarantees', 'Can I give -1000 stars?', 'Outrageous attitude of account…', 'Great and reliable (prime)', "I've enjoyed Amazon for years but…", 'Amazon has gone way down hill.', 'Such worst app eva..', 'If they had a zero star rating would be…', 'I have been buying from Amazon a lot in…', 'Delivery driver lied, never showed and claimed no access to the property', 'They signed me up for prime without my consent', 'All I needed was to change my old work…', 'Best best best service of all', 'Next Day Shipping is Great', 'Absolutely horrible', 'wrost amazon service , product or seller have good produt', 'All of the stuff I order from here is…', 'Again', 'The worst online place to buy from is amazon', 'Amazon is a modern miracle', 'Got rid of postage one.', 'Ridiculous delivery delays',
# ...

# %%
# Out:
# 4160

# %%
#import requests
#from bs4 import BeautifulSoup

#r = requests.get('http://store.steampowered.com/tags/en-us/RPG/')
#soup = BeautifulSoup(r.text, 'lxml')

#def get_pages_no(soup):
 #   total_items = int(soup.find('span', id='NewReleases_total').text)
  #  items_per_page = int(soup.find('span', id='NewReleases_end').text)
   # return round(total_items/items_per_page)

#print(get_pages_no(soup))
# Out:
# 17

# %%
"""import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# Set the URL you want to webscrape from
url = 'http://web.mta.info/developers/turnstile.html'

# Connect to the URL
response = requests.get(url)

# Parse HTML and save to BeautifulSoup object¶
soup = BeautifulSoup(response.text, "html.parser")

# To download the whole data set, let's do a for loop through all a tags
for i in range(36,len(soup.findAll('a'))+1): #'a' tags are for links
    one_a_tag = soup.findAll('a')[i]
    link = one_a_tag['href']
    download_url = 'http://web.mta.info/developers/'+ link
    urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:]) 
    time.sleep(1) #pause the code for a sec"""
# Out:
# 'import requests\nimport urllib.request\nimport time\nfrom bs4 import BeautifulSoup\n\n# Set the URL you want to webscrape from\nurl = \'http://web.mta.info/developers/turnstile.html\'\n\n# Connect to the URL\nresponse = requests.get(url)\n\n# Parse HTML and save to BeautifulSoup object¶\nsoup = BeautifulSoup(response.text, "html.parser")\n\n# To download the whole data set, let\'s do a for loop through all a tags\nfor i in range(36,len(soup.findAll(\'a\'))+1): #\'a\' tags are for links\n    one_a_tag = soup.findAll(\'a\')[i]\n    link = one_a_tag[\'href\']\n    download_url = \'http://web.mta.info/developers/\'+ link\n    urllib.request.urlretrieve(download_url,\'./\'+link[link.find(\'/turnstile_\')+1:]) \n    time.sleep(1) #pause the code for a sec'
