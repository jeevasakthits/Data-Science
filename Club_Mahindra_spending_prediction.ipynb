# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler # Used for scaling of data
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
# Read in train data
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
val=list()
for i in range(df_test.shape[0]):
  val.append(100)

# %%
# Out:
# 3.1911537156307928

# %%
 boxplot = df_train.boxplot(column=['resort_region_code'])

# %%
boxplot = df_train.boxplot(column=[
 'channel_code',
 'main_product_code',
 'numberofadults',
 'numberofchildren',
 'resort_type_code',
 'room_type_booked_code',
 'roomnights',
 'season_holidayed_code',
 'state_code_residence',
 'state_code_resort',
 'total_pax'])

# %%
temp=df_train
df_train.columns.values.tolist()
# Out:
# ['reservation_id',
#  'booking_date',
#  'checkin_date',
#  'checkout_date',
#  'channel_code',
#  'main_product_code',
#  'numberofadults',
#  'numberofchildren',
#  'persontravellingid',
#  'resort_region_code',
#  'resort_type_code',
#  'room_type_booked_code',
#  'roomnights',
#  'season_holidayed_code',
#  'state_code_residence',
#  'state_code_resort',
#  'total_pax',
#  'member_age_buckets',
#  'booking_type_code',
#  'memberid',
#  'cluster_code',
#  'reservationstatusid_code',
#  'resort_id',
#  'amount_spent_per_room_night_scaled']

# %%
df_train=df_train.drop([df_train.shape[0]-1], axis=0)

# %%
#data cleaning using python
temp=df_train
df_train.columns.values.tolist()
# Out:
# ['reservation_id',
#  'booking_date',
#  'checkin_date',
#  'checkout_date',
#  'channel_code',
#  'main_product_code',
#  'numberofadults',
#  'numberofchildren',
#  'persontravellingid',
#  'resort_region_code',
#  'resort_type_code',
#  'room_type_booked_code',
#  'roomnights',
#  'season_holidayed_code',
#  'state_code_residence',
#  'state_code_resort',
#  'total_pax',
#  'member_age_buckets',
#  'booking_type_code',
#  'memberid',
#  'cluster_code',
#  'reservationstatusid_code',
#  'resort_id',
#  'amount_spent_per_room_night_scaled']

# %%
df_train.dropna(inplace = True)

# %%
df_train.drop(columns =['reservation_id','booking_date','memberid','resort_id'], inplace = True) 

df_train
# Out:
#       checkin_date checkout_date  channel_code  main_product_code  \
# 0         05/04/18      06/04/18           3.0                1.0
# 1         11/04/15      16/04/15           1.0                1.0
# 2         01/02/15      05/02/15           1.0                1.0
# 3         11/06/15      16/06/15           1.0                1.0
# 4         14/12/15      19/12/15           1.0                1.0
# 5         12/01/16      13/01/16           1.0                1.0
# 6         20/01/16      21/01/16           3.0                1.0
# 7         20/10/16      25/10/16           1.0                1.0
# 8         18/09/16      24/09/16           1.0                1.0
# 9         21/11/16      24/11/16           1.0                1.0
# 10        28/02/17      01/03/17           2.0                1.0
# 11        18/10/17      20/10/17           2.0                1.0
# 12        25/01/18      26/01/18           3.0                1.0
# ...

# %%
le = preprocessing.LabelEncoder()
li=[]

# %%
mylist = set(df_train.member_age_buckets)
myset = list(mylist)
myval=sorted(myset)
li.append(myval)

# %%
mylist = set(df_train.cluster_code)
myset = list(mylist)
myval=sorted(myset)
li.append(myval)

# %%
mylist = set(df_train.reservationstatusid_code)
myset = list(mylist)
myval=sorted(myset)
li.append(myval)

# %%
li
# Out:
# [['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  ['A', 'B', 'C', 'D', 'E', 'F'],
#  ['A', 'B', 'C']]

# %%
#df_train=temp1
df_train.member_age_buckets=df_train.member_age_buckets.replace( li[0], list(range(len(li[0]))))
df_train.cluster_code=df_train.cluster_code.replace( li[1], list(range(len(li[1]))))
df_train.reservationstatusid_code=df_train.reservationstatusid_code.replace( li[2], list(range(len(li[2]))))

# %%
temp=df_train

# %%
df_train.to_csv("midified.csv")

# %%
temp2=df_train
df_train
# Out:
#       checkin_date checkout_date  channel_code  main_product_code  \
# 0         05/04/18      06/04/18           3.0                1.0
# 1         11/04/15      16/04/15           1.0                1.0
# 2         01/02/15      05/02/15           1.0                1.0
# 3         11/06/15      16/06/15           1.0                1.0
# 4         14/12/15      19/12/15           1.0                1.0
# 5         12/01/16      13/01/16           1.0                1.0
# 6         20/01/16      21/01/16           3.0                1.0
# 7         20/10/16      25/10/16           1.0                1.0
# 8         18/09/16      24/09/16           1.0                1.0
# 9         21/11/16      24/11/16           1.0                1.0
# 10        28/02/17      01/03/17           2.0                1.0
# 11        18/10/17      20/10/17           2.0                1.0
# 12        25/01/18      26/01/18           3.0                1.0
# ...

# %%
df_train.to_csv("train_modified.csv")

# %%
df_train.info()
type(df_train.checkin_date)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27594 entries, 0 to 27878
# Data columns (total 20 columns):
# checkin_date                          27594 non-null object
# checkout_date                         27594 non-null object
# channel_code                          27594 non-null float64
# main_product_code                     27594 non-null float64
# numberofadults                        27594 non-null float64
# numberofchildren                      27594 non-null float64
# persontravellingid                    27594 non-null float64
# resort_region_code                    27594 non-null float64
# resort_type_code                      27594 non-null float64
# room_type_booked_code                 27594 non-null float64
# roomnights                            27594 non-null float64
# season_holidayed_code                 27594 non-null float64
# state_code_residence                  27594 non-null float64
# state_code_resort                     27594 non-null float64
# ...

# %%
from datetime import datetime

# %%
temp=temp2

# %%
modfied=pd.read_csv("midified.csv")

# %%
modfied
# Out:
#        Unnamed: 0 checkin_date checkout_date  channel_code  main_product_code  \
# 0               0     05/04/18      06/04/18           3.0                1.0
# 1               1     11/04/15      16/04/15           1.0                1.0
# 2               2     01/02/15      05/02/15           1.0                1.0
# 3               3     11/06/15      16/06/15           1.0                1.0
# 4               4     14/12/15      19/12/15           1.0                1.0
# 5               5     12/01/16      13/01/16           1.0                1.0
# 6               6     20/01/16      21/01/16           3.0                1.0
# 7               7     20/10/16      25/10/16           1.0                1.0
# 8               8     18/09/16      24/09/16           1.0                1.0
# 9               9     21/11/16      24/11/16           1.0                1.0
# 10             10     28/02/17      01/03/17           2.0                1.0
# ...

# %%
df_train=modfied
for i in range(df_train.shape[0]):
    df_train.checkin_date[i]=datetime.strptime(str(df_train.checkin_date[i]), '%d/%m/%y') 
    df_train.checkout_date[i]=datetime.strptime(str(df_train.checkout_date[i]), '%d/%m/%y') 
df_train.to_csv("train_modified.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import datetime, calendar

# %%
li=[]

for i in range(df_train.shape[0]):
    li.append(calendar.timegm(df_train.checkout_date[i].timetuple())-calendar.timegm(df_train.checkin_date[i].timetuple()))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
li
# Out:
# [86400,
#  432000,
#  345600,
#  432000,
#  432000,
#  86400,
#  86400,
#  432000,
#  518400,
#  259200,
#  86400,
#  172800,
#  86400,
#  172800,
#  86400,
#  259200,
#  86400,
#  172800,
#  259200,
#  345600,
#  345600,
#  259200,
#  172800,
#  259200,
#  172800,
#  86400,
#  172800,
#  259200,
#  172800,
#  259200,
#  86400,
#  86400,
#  86400,
#  172800,
#  518400,
#  86400,
#  86400,
#  172800,
#  172800,
#  259200,
#  86400,
#  86400,
#  86400,
#  259200,
#  259200,
#  345600,
#  86400,
#  259200,
#  172800,
#  259200,
#  86400,
#  86400,
#  259200,
#  259200,
#  172800,
#  259200,
#  172800,
#  172800,
#  172800,
#  172800,
#  86400,
#  172800,
#  172800,
#  172800,
#  259200,
#  172800,
#  86400,
#  172800,
#  172800,
#  86400,
#  86400,
#  259200,
#  86400,
#  172800,
#  172800,
#  259200,
#  345600,
#  172800,
#  172800,
#  345600,
#  259200,
#  259200,
#  172800,
#  259200,
#  86400,
#  172800,
#  86400,
#  86400,
#  172800,
#  172800,
#  86400,
#  345600,
#  172800,
# ...

# %%
modfied=pd.read_csv("midified.csv")

# %%
df_train=modfied

# %%
df_train.checkin_date=li

# %%
df_train.drop(columns =['Unnamed: 0','checkout_date'], inplace = True)

# %%
df_train.to_csv("midified.csv")

# %%
temp=df_train
df_train.columns.values.tolist()
# Out:
# ['checkin_date',
#  'channel_code',
#  'main_product_code',
#  'numberofadults',
#  'numberofchildren',
#  'persontravellingid',
#  'resort_region_code',
#  'resort_type_code',
#  'room_type_booked_code',
#  'roomnights',
#  'season_holidayed_code',
#  'state_code_residence',
#  'state_code_resort',
#  'total_pax',
#  'member_age_buckets',
#  'booking_type_code',
#  'cluster_code',
#  'reservationstatusid_code',
#  'amount_spent_per_room_night_scaled']

# %%
#scatterplot

sns.set()
cols = ['checkin_date',
 'channel_code',
 'main_product_code',
 'numberofadults',
 'numberofchildren',
 'persontravellingid',
 'resort_region_code',
 'resort_type_code',
 'room_type_booked_code',
 'roomnights',
 'season_holidayed_code',
 'state_code_residence',
 'state_code_resort',
 'total_pax',
 'member_age_buckets',
 'booking_type_code',
 'cluster_code',
 'reservationstatusid_code']
sns.pairplot(df_train[cols], size = 2.5)
plt.show();


#missing data
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)

df_train = df_train.fillna(df_train.mean())

#standardizing data
amount_spent_per_room_night_scaled_scaled = StandardScaler().fit_transform(df_train['amount_spent_per_room_night_scaled'][:,np.newaxis]);
low_range = amount_spent_per_room_night_scaled_scaled[amount_spent_per_room_night_scaled_scaled[:,0].argsort()][:10]
high_range= amount_spent_per_room_night_scaled_scaled[amount_spent_per_room_night_scaled_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# outer range (low) of the distribution:
# [[-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]
#  [-0.83189633]]
#
# outer range (high) of the distribution:
# [[1.89167146]
#  [1.90023452]
#  [1.90098946]
#  [1.90751717]
#  [1.91013577]
#  [1.91320784]
#  [1.93082311]
#  [1.93750011]
#  [1.94236799]
#  [1.94658097]]

# %%
df_train
# Out:
#        checkin_date  channel_code  main_product_code  numberofadults  \
# 0             86400           3.0                1.0             2.0
# 1            432000           1.0                1.0             2.0
# 2            345600           1.0                1.0             2.0
# 3            432000           1.0                1.0             2.0
# 4            432000           1.0                1.0             2.0
# 5             86400           1.0                1.0             2.0
# 6             86400           3.0                1.0             2.0
# 7            432000           1.0                1.0             2.0
# 8            518400           1.0                1.0             2.0
# 9            259200           1.0                1.0             2.0
# 10            86400           2.0                1.0             2.0
# 11           172800           2.0                1.0             2.0
# 12            86400           3.0                1.0             2.0
# ...

# %%
trin=pd.read_csv("train.csv")

# %%
df_train.shape[0]
# Out:
# 27592

# %%
cols = ['checkin_date',
 'channel_code',
 'main_product_code',
 'numberofadults',
 'numberofchildren',
 'persontravellingid',
 'resort_region_code',
 'resort_type_code',
 'room_type_booked_code',
 'roomnights',
 'season_holidayed_code',
 'state_code_residence',
 'state_code_resort',
 'total_pax',
 'member_age_buckets',
 'booking_type_code',
 'cluster_code',
 'reservationstatusid_code','amount_spent_per_room_night_scaled']
df_train = df_train[cols]
# Create dummy values
df_train = pd.get_dummies(df_train)
#filling NA's with the mean of the column:
df_train = df_train.fillna(df_train.mean())
# Always standard scale the data before using NN
scale = StandardScaler()
X_train = df_train[['checkin_date',
 'channel_code',
 'main_product_code',
 'numberofadults',
 'numberofchildren',
 'persontravellingid',
 'resort_region_code',
 'resort_type_code',
 'room_type_booked_code',
 'roomnights',
 'season_holidayed_code',
 'state_code_residence',
 'state_code_resort',
 'total_pax',
 'member_age_buckets',
 'booking_type_code',
 'cluster_code',
 'reservationstatusid_code']]


X_train = scale.fit_transform(X_train)
# Y is just the 'amount_spent_per_room_night_scaled' column
y = df_train['amount_spent_per_room_night_scaled'].values
X_train1=X_train[0:trin.shape[0]]
y_train=y[0:trin.shape[0]]
X_test=X_train[trin.shape[0]:]
y_test=y[trin.shape[0]:]
X_train=X_train1


def create_model():
    # create model
    model = Sequential()
    model.add(Dense(30, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(90, activation='relu'))
    model.add(Dense(90, activation='relu'))
    model.add(Dense(90, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', 
              metrics =[metrics.mae])
    return model

model = create_model()
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 30)                570
# _________________________________________________________________
# dense_2 (Dense)              (None, 90)                2790
# _________________________________________________________________
# dense_3 (Dense)              (None, 90)                8190
# _________________________________________________________________
# dense_4 (Dense)              (None, 90)                8190
# _________________________________________________________________
# ...

# %%
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=200, batch_size=32)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 11642 samples, validate on 15950 samples
# Epoch 1/100
# 11642/11642 [==============================] - 1s 128us/step - loss: 4.9869 - mean_absolute_error: 1.5000 - val_loss: 58.5101 - val_mean_absolute_error: 7.6080
# Epoch 2/100
# 11642/11642 [==============================] - 1s 70us/step - loss: 1.9251 - mean_absolute_error: 0.9528 - val_loss: 56.0211 - val_mean_absolute_error: 7.4628
# Epoch 3/100
# 11642/11642 [==============================] - 1s 73us/step - loss: 1.7707 - mean_absolute_error: 0.8930 - val_loss: 55.1273 - val_mean_absolute_error: 7.4040
# Epoch 4/100
# ...

# %%
prediction= model.predict(X_test)

# %%
prediction
# Out:
# array([[6.9891386],
#        [7.338402 ],
#        [7.810067 ],
#        ...,
#        [7.371485 ],
#        [8.959487 ],
#        [7.4823403]], dtype=float32)

# %%
submission = pd.DataFrame()
submission['amount_spent_per_room_night_scaled'] = prediction[:,0]
submission.to_csv("output.csv")

# %%
from sklearn.metrics import confusion_matrix

rmse = sqrt(mean_squared_error(y_test, prediction))


model.summary()

rmse
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 30)                570
# _________________________________________________________________
# dense_2 (Dense)              (None, 90)                2790
# _________________________________________________________________
# dense_3 (Dense)              (None, 90)                8190
# _________________________________________________________________
# dense_4 (Dense)              (None, 90)                8190
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 91
# ...
# Total params: 19,831
# Trainable params: 19,831
# Non-trainable params: 0
# _________________________________________________________________
# 0.7010580776498702

# %%
#
#from sklearn import metrics as ms
mse=mean_squared_error(y_test, prediction)
print("Mean Square Error",mse)
#print("Accuracy:", ms.accuracy_score(y_test,predictn))
# Out:
# Mean Square Error 58.531996760951735

# %%
# summarize history for accuracy
plt.plot(y_test)
plt.plot(predictn)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['test original', 'prediction'], loc='upper left')
plt.show()
# summarize

# %%
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
